# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("navoneel/brain-mri-images-for-brain-tumor-detection")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'brain-mri-images-for-brain-tumor-detection' dataset.
# Path to dataset files: /kaggle/input/brain-mri-images-for-brain-tumor-detection

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
train_dir = path + "/brain_tumor_dataset"

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    train_dir,
    target_size=(128,128),
    batch_size=16,
    class_mode='binary',
    subset='training'
)

val_data = datagen.flow_from_directory(
    train_dir,
    target_size=(128,128),
    batch_size=16,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 203 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.

# %%
model = Sequential()

model.add(Conv2D(32,(3,3),activation='relu',input_shape=(128,128,3)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(128,activation='relu'))

model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#compile
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
#training
history = model.fit(
    train_data,
    epochs=10,
    validation_data=val_data
)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 415ms/step - accuracy: 0.6700 - loss: 0.7600 - val_accuracy: 0.7400 - val_loss: 0.5504
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 511ms/step - accuracy: 0.8079 - loss: 0.4783 - val_accuracy: 0.8000 - val_loss: 0.5444
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 394ms/step - accuracy: 0.8424 - loss: 0.3862 - val_accuracy: 0.7600 - val_loss: 0.5318
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 365ms/step - accuracy: 0.8966 - loss: 0.2606 - val_accuracy: 0.8200 - val_loss: 0.4802
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 479ms/step - accuracy: 0.9409 - loss: 0.1450 - val_accuracy: 0.8200 - val_loss: 0.4694
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 410ms/step - accuracy: 0.9803 - loss: 0.0676 - val_accuracy: 0.8800 - val_loss: 0.4523
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 473ms/step - accuracy: 1.0000 - loss: 0.0300 - val_accuracy: 0.8200 - val_loss: 0.5906
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 374ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.8800 - val_loss: 0.5077
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 413ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8200 - val_loss: 0.6258
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 370ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8200 - val_loss: 0.6022

# %%
#filter visualization
filters, biases = model.layers[0].get_weights()

plt.figure(figsize=(8,8))

for i in range(6):
    f = filters[:,:,:,i]
    plt.subplot(2,3,i+1)
    plt.imshow(f[:,:,0], cmap='gray')
    plt.axis('off')

plt.suptitle("CNN Filters")
plt.show()

# %%
#evaluation
loss, accuracy = model.evaluate(val_data)

print("Validation Accuracy:", accuracy)
print("Validation Loss:", loss)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8200 - loss: 0.6022
# Validation Accuracy: 0.8199999928474426
# Validation Loss: 0.6022295355796814

# %%
import cv2

img = train_data[0][0][0]

heatmap = np.mean(img, axis=-1)

plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.5)
plt.title("Class Activation Map")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(127.5), np.float64(127.5), np.float64(-0.5))
